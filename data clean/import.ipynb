# %%
import pandas as pd

df = pd.read_spss('/Users/apple/Documents/GitHub/TJ-sem-project/data0612_family.sav')

# %%
df
# Out:
#      Q1线上社会支持1_中心化C  Q2线上社会支持2_中心化C  Q3线上社会支持3_中心化C  Q4线下社会支持1_中心化C  \
# 0          0.376278        0.634969        1.408998        0.349693
# 1         -0.623722        0.634969        0.408998       -0.650307
# 2          0.376278        1.634969        0.408998       -0.650307
# 3          1.376278        0.634969        0.408998        1.349693
# 4         -1.623722       -0.365031       -0.591002        0.349693
# ..              ...             ...             ...             ...
# 973        0.376278       -0.365031        0.408998        1.349693
# 974        1.376278        0.634969        1.408998        0.349693
# 975       -0.623722       -1.365031       -1.591002       -0.650307
# 976       -2.623722       -1.365031       -1.591002       -1.650307
# 977        1.376278        0.634969        0.408998       -0.650307
#
#      Q5线下社会支持2_中心化C  Q6线下社会支持3_中心化C       XS1       XS2       XS3      XS4  \
# ...

# %%
#SEN modeling testing
